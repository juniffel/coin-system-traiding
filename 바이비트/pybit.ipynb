# %%
pip install pybit

# %%
pip install --upgrade pip

# %%
from pybit.unified_trading import HTTP, WebSocket
import pandas as pd
pd.set_option("display.max_columns", None)
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
########  Defines ###########################
testnet = False

###############################################
with open('key.txt') as f:
    lines = f.readlines()
    api_key = lines[0].strip()
    secret = lines[1].strip()
    
session = HTTP(testnet = testnet, api_key = api_key,api_secret = secret, logging_level = 10,)

# %%
def klines(category, symbol, interval, limit=1000 ):
	df = pd.DataFrame(session.get_kline(
	category="linear",
	symbol="BTCUSDT",
	interval=60,   
	)['result']['list'])
	# 열에 이름 지정 
	df.columns = ['date', 'open', 'high', 'low', 'close', 'volume', 'turnover']
	# 타임스탬프를 날짜 형식으로 변환하고 ohlcv가 모두 숫자인지 확인합니다. 
	df['date'] = pd.to_datetime(df['date'], unit='ms') 
	for col in df.columns[1:]: 
		df[col ] = pd.to_numeric(df[col])
	return df

klines(category="linear",
	symbol="BTCUSDT",
	interval=60,
 	limit=10)
# Out:
# C:\Users\wnsdu\AppData\Local\Temp\ipykernel_17156\12459027.py:10: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['date'] = pd.to_datetime(df['date'], unit='ms')
#                        date     open     high      low    close     volume  \
# 0   2024-04-30 13:00:53.120  61214.9  61247.8  61022.0  61247.8   1480.937
# 1   2024-04-30 11:59:43.104  61194.5  61328.9  60703.0  61214.9  10697.814
# 2   2024-04-30 11:00:44.160  61754.3  61754.4  61001.7  61194.5  12001.738
# 3   2024-04-30 09:59:34.144  61645.5  61760.3  61350.0  61754.3   7447.350
# 4   2024-04-30 09:00:35.200  61878.5  62080.0  61515.0  61645.5  11572.347
# ..                      ...      ...      ...      ...      ...        ...
# 195 2024-04-22 10:00:31.488  65914.4  66123.0  65860.4  66017.5   2154.299
# 196 2024-04-22 08:59:21.472  65936.1  66031.4  65753.0  65914.4   1869.694
# 197 2024-04-22 08:00:22.528  65936.0  66180.0  65877.0  65936.1   2488.241
# 198 2024-04-22 06:59:12.512  66279.5  66455.0  65928.9  65936.0   3180.417
# 199 2024-04-22 06:00:13.568  66350.0  66385.2  66125.0  66279.5   3274.771
#
#          turnover
# 0    9.053395e+07
# 1    6.533003e+08
# 2    7.356860e+08
# 3    4.588254e+08
# 4    7.155229e+08
# ..            ...
# 195  1.421836e+08
# 196  1.231898e+08
# 197  1.642865e+08
# 198  2.103342e+08
# 199  2.169496e+08
#
# [200 rows x 7 columns]

# %%
#종목들

df = pd.DataFrame(session.get_tickers(
    category="linear",
)['result']['list'])

df.sort_values('price24hPcnt', ascending=False).reset_index(drop = True)
# Out:
#         symbol lastPrice indexPrice markPrice prevPrice24h price24hPcnt  \
# 0     ZETAUSDT    1.1825     1.1846    1.1832       1.1485     0.029603
# 1    STEEMUSDT    0.2779     0.2785    0.2782       0.2724      0.02019
# 376    1.0000    1.0001  58756.3
#
# [377 rows x 24 columns]

# %%
# 코인 정보
pd.set_option('display.max_colwidth', None)
pd.DataFrame(session.get_instruments_info(
    category="linear",
    symbol="BTCUSDT",
)['result']['list'])
# Out:
#     symbol     contractType   status baseCoin quoteCoin     launchTime  \
# 0  BTCUSDT  LinearPerpetual  Trading      BTC      USDT  1584230400000
#
#   deliveryTime deliveryFeeRate priceScale  \
# 0            0                          2
#
#                                                           leverageFilter  \
# 0  {'minLeverage': '1', 'maxLeverage': '100.00', 'leverageStep': '0.01'}
#
#                                                          priceFilter  \
# 0  {'minPrice': '0.10', 'maxPrice': '199999.80', 'tickSize': '0.10'}
#
#                                                                                                                                                       lotSizeFilter  \
# 0  {'maxOrderQty': '1190.000', 'minOrderQty': '0.001', 'qtyStep': '0.001', 'postOnlyMaxOrderQty': '1190.000', 'maxMktOrderQty': '119.000', 'minNotionalValue': '5'}
#
#    unifiedMarginTrade  fundingInterval settleCoin copyTrading  \
# 0                True              480       USDT        both
#
#   upperFundingRate lowerFundingRate
# 0          0.00375         -0.00375

# %%
# 주문 하기
session.place_order(
    category="spot",
    symbol="BTCUSDT",
    side="Buy",
    orderType="Limit",
    qty="0.1",
    price="15600",
    timeInForce="PostOnly",
    orderLinkId="spot-test-postonly",
    isLeverage=0,
    orderFilter="Order",
)

# %%
# 주문 취소

session.cancel_order(
    category="linear",
    symbol="BTCPERP",
    orderId="c6f055d9-7f21-4079-913d-e6523a9cfffa",
)

# %%
# 포지션 정보
session.get_positions(
    category="linear",
    settleCoin = 'USDT'
)
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'list': [], 'nextPageCursor': '', 'category': 'linear'},
#  'retExtInfo': {},
#  'time': 1714491763758}

# %%
#레버리지 설정
session.set_leverage(
    category="linear",
    symbol="BTCUSDT",
    buyLeverage="6",
    sellLeverage="6",
)
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {},
#  'retExtInfo': {},
#  'time': 1714475563555}

# %%
#마진 설정
session.switch_margin_mode(
    category="linear",
    symbol="ETHUSDT",
    tradeMode=1, # cross:0, isolated:1
    buyLeverage="10",
    sellLeverage="10",
)

# %%
#TP/SL모드
session.set_tp_sl_mode(
    symbol="XRPUSDT",
    category="linear",
    tpSlMode="Full",
)

# %%
#트레이딩 스탑
session.set_trading_stop(
    category="linear",
    symbol="XRPUSDT",
    takeProfit="0.6",
    stopLoss="0.2",
    tpTriggerBy="MarkPrice",
    slTriggerB="IndexPrice",
    tpslMode="Partial",
    tpOrderType="Limit",
    slOrderType="Limit",
    tpSize="50",
    slSize="50",
    tpLimitPrice="0.57",
    slLimitPrice="0.21",
    positionIdx=0,
)

# %%
#자산 정보
session.get_wallet_balance(
    accountType="CONTRACT",
    coin="BTC",
)
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'list': [{'accountType': 'CONTRACT',
#     'accountIMRate': '',
#     'accountMMRate': '',
#     'totalEquity': '',
#     'totalWalletBalance': '',
#     'totalMarginBalance': '',
#     'totalAvailableBalance': '',
#     'totalPerpUPL': '',
#     'totalInitialMargin': '',
#     'totalMaintenanceMargin': '',
#     'accountLTV': '',
#     'coin': [{'coin': 'BTC',
#       'equity': '0',
#       'usdValue': '',
#       'walletBalance': '0',
#       'borrowAmount': '',
#       'availableToBorrow': '',
#       'availableToWithdraw': '0',
#       'accruedInterest': '',
#       'totalOrderIM': '0',
#       'totalPositionIM': '0',
#       'totalPositionMM': '',
#       'unrealisedPnl': '0',
#       'cumRealisedPnl': '0'}]}]},
#  'retExtInfo': {},
#  'time': 1714475750340}

# %%
#계정정보
session.get_account_info()
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'marginMode': 'REGULAR_MARGIN',
#   'updatedTime': '0',
#   'unifiedMarginStatus': 1,
#   'dcpStatus': 'OFF',
#   'timeWindow': 10,
#   'smpGroup': 0,
#   'isMasterTrader': False,
#   'spotHedgingStatus': 'OFF'}}

# %%
# 자산정보
session.get_spot_asset_info(
    accountType="FUND",
    coin="USDC",
)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[21], line 2
#       1 # 자산정보
# ----> 2 session.get_spot_asset_info(
#       3     accountType="FUND",
#       4     coin="USDC",
#       5 )
#
# File c:\Users\wnsdu\AppData\Local\Programs\Python\Python310\lib\site-packages\pybit\_v5_asset.py:72, in AssetHTTP.get_spot_asset_info(self, **kwargs)
#      60 def get_spot_asset_info(self, **kwargs):
#      61     """Query asset information
#      62
#      63     Required args:
#    (...)
#      70         https://bybit-exchange.github.io/docs/v5/asset/asset-info
#      71     """
# ---> 72     return self._submit_request(
#      73         method="GET",
#      74         path=f"{self.endpoint}{Asset.GET_SPOT_ASSET_INFO}",
#      75         query=kwargs,
#      76         auth=True,
#      77     )
#
# File c:\Users\wnsdu\AppData\Local\Programs\Python\Python310\lib\site-packages\pybit\_http_manager.py:379, in _V5HTTPManager._submit_request(self, method, path, query, auth)
#     376         pass
#     378     else:
# --> 379         raise InvalidRequestError(
#     380             request=f"{method} {path}: {req_params}",
#     381             message=s_json[ret_msg],
#     382             status_code=s_json[ret_code],
#     383             time=dt.utcnow().strftime("%H:%M:%S"),
#     384             resp_headers=s.headers,
#     385         )
#     386 else:
#     387     if self.log_requests:
#
# InvalidRequestError: request parameter err: account_type illegal temporary spot support (ErrCode: 131203) (ErrTime: 09:08:31).
# Request → GET https://api.bybit.com/v5/asset/transfer/query-asset-info: accountType=FUND&coin=USDC.
